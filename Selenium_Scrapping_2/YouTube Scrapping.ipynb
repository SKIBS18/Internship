# %%
from selenium import webdriver

# %%
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
from time import sleep

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r'C:\Users\shail\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url = 'https://www.youtube.com/watch?v=sPHOKgkq3rI'
driver.get(url)

# %%
comment = []

c = driver.find_elements(By.ID,'content-text')

for i in c:
    comment.append(i.text)

# %%
len(comment)
# Out:
# 724

# %%
cmnt = comment[0:500]

# %%
cmnt
# Out:
# ['Rohit ki bating k duniya fan hai but mai Rohit capticicy ka fan ho gya love you Hitman',
#  'Rohit Sharma is built different, make his presence feel, works with mind and no over agression.\nAbsolutely brilliant ️',
#  'When Rohit comes in team I always see that winning intent and results always comes in favour',
#  'Extremely happy to see India winning T20 series against formidable England side. My heart goes out for players like Rohit, Pandya, Bhuvi, Chahal, Jadeja & Sky who made it happen.',
#  'Today rohit showed how good a captain he is and why MI are 5 time champions his captaincy  and changes today were absolutely brilliant  170 was a middling score  but rohit made it huge with his brilliant captaincy and changes ',
#  'अजबगजब कप्तानी रोहित शर्मा जी   कप्तान साहब ने दिखा दिया कि टेस्ट मैच से हमें भारत ने क्यों मिस किया',
#  'रोहित शर्मा को पहले कप्तान बनाया गया होता तो, भारत ने world Cup जीता होता.',
# ...

# %%
time = []

g = driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')

for t in g:
    time.append(t.text)

# %%
time
# Out:
# ['3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '2 weeks ago',
#  '3 weeks ago',
# ...

# %%
len(time)
# Out:
# 724

# %%
t = time[0:500]

# %%
t
# Out:
# ['3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '3 weeks ago (edited)',
#  '3 weeks ago',
#  '2 weeks ago',
#  '3 weeks ago',
# ...

# %%
vote = []

vot = driver.find_elements(By.XPATH,'//*[@id="vote-count-middle"]')
for a in vot:
    vote.append(a.get_attribute("aria-label"))

# %%
vote
# Out:
# ['48 likes',
#  '213 likes',
#  '251 likes',
#  '175 likes',
#  '256 likes',
#  '209 likes',
#  '17 likes',
#  '205 likes',
#  '87 likes',
#  '148 likes',
#  '79 likes',
#  '117 likes',
#  '21 likes',
#  '109 likes',
#  '37 likes',
#  '38 likes',
#  '105 likes',
#  '75 likes',
#  '26 likes',
#  '46 likes',
#  '15 likes',
#  '140 likes',
#  '3 likes',
#  '18 likes',
#  '94 likes',
#  '32 likes',
#  '86 likes',
#  '49 likes',
#  '30 likes',
#  '19 likes',
#  '12 likes',
#  '47 likes',
#  '58 likes',
#  '7 likes',
#  '18 likes',
#  '15 likes',
#  '5 likes',
#  '39 likes',
#  '21 likes',
#  '12 likes',
#  '5 likes',
#  '2 likes',
#  '39 likes',
#  '32 likes',
#  '4 likes',
#  '18 likes',
#  '15 likes',
#  '14 likes',
#  '71 likes',
#  '14 likes',
#  '1 like',
#  '18 likes',
#  '8 likes',
#  '2 likes',
#  None,
#  '7 likes',
#  '39 likes',
#  '25 likes',
#  '405 likes',
#  '1 like',
#  '22 likes',
#  '39 likes',
#  '5 likes',
#  None,
#  '18 likes',
#  '7 likes',
#  '29 likes',
# ...

# %%
len(vote)
# Out:
# 724

# %%
v = vote[0:500]

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Comment':cmnt,'Time':t,'Vote':v})
df
# Out:
#                                                Comment         Time       Vote
# 0    Rohit ki bating k duniya fan hai but mai Rohit...  3 weeks ago   48 likes
# 1    Rohit Sharma is built different, make his pres...  3 weeks ago  213 likes
# 2    When Rohit comes in team I always see that win...  3 weeks ago  251 likes
# 3    Extremely happy to see India winning T20 serie...  3 weeks ago  175 likes
# 4    Today rohit showed how good a captain he is an...  3 weeks ago  256 likes
# ..                                                 ...          ...        ...
# 495  Team sports Tak don't predict our Indian team....  3 weeks ago     1 like
# 496  Sai bajai hai England ki lekin ben stokes Blai...  3 weeks ago       None
# 497         Abhi test haraaya hai bhai... Itna mt haso  3 weeks ago       None
# 498         ab pata chal gya virat is bigger than bcci  3 weeks ago       None
# 499                    drop Kohli and add Deepak hooda  3 weeks ago       None
#
# [500 rows x 3 columns]
